# %%
def pactorial(n):
  if n == 1:
    
    return 1
  result = pactorial(n-1) * n
  print(result)
  return result

pactorial(5)
# Out:
# 2
# 6
# 24
# 120
# 120

# %%
def gcd(a, b):
  if a == b:
    return a
  small = min(a, b)
  big = max(a, b)
  return gcd(small, big - small)

print(gcd(27, 15))
# Out:
# 3

# %%
def quickSort(arr):
  if len(arr) <= 1:
    return arr
  
  pivot = 0

  left = []
  right = []
