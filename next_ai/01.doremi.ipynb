# %%
# /는 실수 나눗셈, //은 몫 나눗셈, **은 제곱
print(5 // 2, 2 ** 4)
# 문자열 덧셈은 합해지고 곱셈은 반복이다.
print("안녕" + "하세요")
print("안녕" * 3)
# Out:
# 2 16
# 안녕하세요
# 안녕안녕안녕

# %%
# 문자열도 리스트처럼 여러 원소로 이루어져 있어 []로 접근 가능하다.
alpha = "Ready"

# indexing: index를 이용해서 문자열과 리스트의 특정 문자열을 가져오는 방법
print(alpha[1])

# slicing: 문자열과 리스트의 원소 '일부'를 들고오는 것
# 문법: String/list[시작 인덱스:종료 인덱스] - 이상 미만의 법칙
print(alpha[2:4])
# Out:
# e
# ad

# %%
# 숫자를 입력하세요는 변수에 들어가지 않음
var = input("숫자를 입력하세요: ")

print(var)
# input에 반환되는 데이터는 str
print(type(var))
# Out:
# <class 'str'>

# %%
# 형 변환
# int는 숫자
# float는 실수  
# str은 문자
# list는 리스트
var2 = int(input("입력"))

print(type(var2))

# 문자열을 리스트로 바꾸면 각 원소가 저장됨
# 숫자는 안 됨
var3 = '3.14'
print(list(var3))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 6
#       1 # 형 변환
#       2 # int는 숫자
#       3 # float는 실수
#       4 # str은 문자
#       5 # list는 리스트
# ----> 6 var2 = int(input("입력"))
#       8 print(type(var2))
#      10 # 문자열을 리스트로 바꾸면 각 원소가 저장됨
#      11 # 숫자는 안 됨
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print('3' == 3)
print('3' == "3")
# Out:
# False
# True

# %%
# append: 오직 한 개의 자료를 마지막에 넣을 수 있는 함수
a = []
b = ['a', 'b', 'c']

a.append(10)
b.append('d')
print(a, b)

# insert: 몇 번째 인덱스에 넣고 싶은 자료를 하나만 넣을 수 있는 함수
# 첫 번째 매개변수: 넣을 인덱스, 두 번째 매개변수: 들어갈 값
c = [1, 2, 4, 5]
c.insert(2, 3)
print(c)

# 원소 하나를 지울 수 있는데 중복될 경우 첫 번째에 발견된 원소가 지워진다.
my_list = [3, 1, 2, 3]
my_list.remove(3)
print(my_list)

# 정렬 함수
# 숫자, 문자가 함께 있으면 사용 불가
e = [2, 1, 4, 3]
f = ['d', 'c', 'b']

e.sort()
f.sort()
print(e, f)

# 꺼내기 함수 
my_list = [2, 3, 5, 7, 11]
# 0번째 요소 꺼내기
print(my_list.pop(0))
# 매개변수가 없으면 0번째 요소를 빼냄
print(my_list.pop())
print(my_list)

# 함수 안에 있는 자료가 몇 개인지 알 수 있는 함수
my_seq = [2, 2, 2, 4, 4]
print(my_seq.count(4))
my_str = "elice and alice"
print(my_str.count('e'))

# 문자열을 쪼개 리스트화하는 함수
# 매개변수 미전달 시 공백을 기준으로 처리
my_str = "1 2 3 4 5"
print(my_str.split())
element = "Na, Mg, Al, Si"
print(element.split(','))

# 리스트를 합쳐서 문자열을 만드는 함수
my_list = ['e', 'l', 'i', 'c', 'e']
print("".join(my_list))
station = ['서울', '대전', '대구']
print("->".join(station))
# Out:
# [10] ['a', 'b', 'c', 'd']
# [1, 2, 3, 4, 5]
# [1, 2, 3]
# [1, 2, 3, 4] ['b', 'c', 'd']
# 2
# 11
# [3, 5, 7]
# 2
# 3
# ['1', '2', '3', '4', '5']
# ['Na', ' Mg', ' Al', ' Si']
# elice
# 서울->대전->대구

# %%
# sequence 자료형: 각 원소에 순서가 있는 자료형
# 종류: 문자열, 리스트  
# 특징
# 1. 인덱싱, 슬라이싱 가능
# 2. 인덱싱, 슬라이싱을 할 때 음수를 넣거나 자리를 비우는 것 가능
#   - a[-1](뒤에서 1번째), a[2:](2번째 인덱스부터 끝까지), a[:4](처음부터 3번째 인덱스까지)
# 3. in 연산자(어떤 원소가 sequence 자료형에 들어있는가를 판별) 사용 가능
# 4. len 연산자(길이 출력) 사용 가능
# 5. 연산 가능(+, *)

# %%
# for문 형태
# 문법: for 시퀸스 자료형의 각 원소를 담을 변수 in 시퀸스 자료형

# %%
# range: 연속된 숫자를 만들어 주는 시퀸스 자료형
# 특징: 시작하는 숫자(a)와 끝나는 숫자(b)를 지정해주면 a ~ (b - 1)까지의 숫자 생성
# 단, range 안의 원소를 보여주는 기능이 없어 list로 형변환을 해서 확인해야 함

# %%
# 튜플: 여러 자료형을 담을 수 있는 자료형이고 안의 내용을 바꿀 수 없다.(sequence 자료형에 포함)
tuple_zero = ()

# %%
# 딕셔너리도 대괄호로 value를 꺼낸다.
person = {
  "name": "Rabbit",
  "age": 22
}

print(person["name"])

# 자료 추가하기
person["mail"] = "rabbit@elice.com"
print(person)

# 자료 삭제하기
del person["age"]
print(person)

# key들만 추출하기
print(person.keys())

# value만 추출하기
print(person.values())

# (key, value) 형태의 리스트로 추출하기
print(person.items())

# key는 중복될 수 없고 변할 수 없는 자료형(튜플 사용 가능)이어야 한다.
dictionary_example = {(1, 2, 3): "hello"}
print(dictionary_example)
# Out:
# Rabbit
# {'name': 'Rabbit', 'age': 22, 'mail': 'rabbit@elice.com'}
# {'name': 'Rabbit', 'mail': 'rabbit@elice.com'}
# dict_keys(['name', 'mail'])
# dict_values(['Rabbit', 'rabbit@elice.com'])
# dict_items([('name', 'Rabbit'), ('mail', 'rabbit@elice.com')])
# {(1, 2, 3): 'hello'}

# %%
# for문 변수는 여러 개 사용 가능
week = [(1, "월"), (2, "화"), (3, "수")]

for num, date in week :
  print(num, date)

# zip 함수: 여러 리스트, 튜플, 문자열 드으이 데이터를 병렬로 묶어 튜플로 반환하는 명령어 - iterator 반환(sequence와 다른 개념)
# 동일한 인덱스에 있는 요소들을 하나의 튜플로 묶음
list1 = ["A", "B", "C"]
list2 = [11, 13, 15, 17]
list3 = [1, 2, 3]
print(zip(list1, list2, list3))
print(list(zip(list1, list2, list3)))
print(dict(zip(list1, list2)))

my_dict = {"a": 11, "b": 13, "c": 17}

for key, value in zip(my_dict.keys(), my_dict.values()) :
  print("key", key, "value", value)
# Out:
# 1 월
# 2 화
# 3 수
# ...
# [('A', 11, 1), ('B', 13, 2), ('C', 15, 3)]
# {'A': 11, 'B': 13, 'C': 15}
# key a value 11
# key b value 13
# key c value 17
