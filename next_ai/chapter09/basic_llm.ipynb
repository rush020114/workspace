# %%
# parameter (w, b): 학습으로 자동 결정됨, 사람이 못 건드림
#   -> 실제로 계산을 수행해서 대답을 만들어냄

# hyperparameter: 사람이 설정하는 값 (parameter와는 다른 개념)
#   1) 학습 하이퍼파라미터 (learning rate, batch size 등)
#      -> 학습 "과정"을 조절, 대답에는 간접적으로만 영향
#   2) 생성 하이퍼파라미터 (temperature, top_p, max_tokens 등)
#      -> 대답 생성 "방식"을 직접 조절
