# %%
# client: server에 service를 요청하는 것
# server: client의 요청에 응답하여 service를 제공
# network: 여러 대의 컴퓨터나 장치들이 서로 연결되어 데이터를 주고받을 수 있는 시스템
# ip주소: 인터넷에서 각 기기를 구별하는 고유한 주소
# nslookup: 해당 홈페이지의 ip주소를 알 수 있다.
# DNS: 도메인 이름과 IP 주소 간의 변환을 처리하는 시스템
# DNS 서버의 역할: 도메인 주소를 받으면 해당 IP로 변환
# server 연결 흐름: 브라우저 -> DNS -> 브라우저 -> 목적지 서버
# PORT: 하나의 IP에 여러 서비스가 돌아갈 때 이를 구별짓는 구분자

# 유니캐스트 — 1:1 전송. 현장 장비 한 대에서 서버 한 대로 데이터 보낼 때
# 멀티캐스트 — 1:다수 전송. 여러 서버 중 구독한 곳에만 보낼 때
# 브로드캐스트 — 1:전체 전송. 네트워크 내 모든 기기에 뿌릴 때

# IP 프로토콜: 주소 지정, 패킷 전달
# IP 프로토콜의 문제: 전송할 때 데이터가 안정성과 순서가 보장되지 않음
# IP 프로토콜 혼자의 문제를 해결하기 위해 나온 것이 TCP 프로토콜
# http에서 데이터가 발생하면 TCP로 전달되어 신뢰성을 챙기고 IP에서 어디로 보낼지 판단을 하고 와이파이나 이더넷으로 전송
# HTTP (데이터 발생)
#  ↓
# TCP (신뢰성 보장)
#  ↓
# IP (주소 지정, 전달)
#  ↓
# 물리 네트워크 (실제 전송)

# http 요청 메시지 -> 도착지, 출발지 정보를 담은 ip 패킷(전송, 인터넷 계층) 감싸기 -> frame 감싸기(네트워크 계층)의 캡슐화를 거침
# 이 프레임을 이더넷, 무선 등으로 보낸다.

# http protocol 특징
# 무상태성: client의 상태를 기억하지 않음(클라이언트는 여러 서버에 요청을 보내기 쉽고(서버의 확장성) 서버도 클라이언트 관리가 쉽다.)
# 비연결성: 요청 응답 후 즉시 종료(자원 최적화 - 다른 클라이언트의 연결에 대응하기 유연)
