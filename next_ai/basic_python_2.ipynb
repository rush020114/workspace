# %%
# 모듈
# 단일 파일로 구성되어 함수, 변수 등을 포함한 코드 블록
# 독립적으로 실행 가능하며 교체가능한 프로그램
# 특징: 특별한 역할을 수행

# 패키지
# 여러 모듈을 모아놓은 폴더
# 관련된 모듈들을 함께 묶어서 관리

# 라이브러리
# 재사용 가능한 코드를 비롯한 다양한 자료들의 집합
# 하나 이상의 모듈이나 패키지가 포함될 수 있음

# 프레임워크
# 특정 애플리케이션을 개발하기 위한 기본 구조와 지원을 제공하는 소프트웨어의 집합
# 예를 들어 웹제작 프레임워크를 사용하면 웹에 대한 기반이 다 갖춰져 있어서 웹을 훨씬 더 빠르게 제작할 수 있다.

# %%
# pip: 파이썬 패키지를 관리하게 해주는 명령어

# %%
# API
# 소프트웨어 간의 상호작용을 가능하게 하는 규약이나 인터페이스
# 어떠한 응용 프로그램(웹 브라우저, 워드 프로세서, 데이터 베이스 등)에서 데이터를 전달해주는 방법
